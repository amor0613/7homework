# %%
import pandas as pd
import mytools
# 导入包

# %%
df = pd.read_csv(R'data\类别变量练习数据.csv',encoding='GBK')
#打开数据文件

# %%
tau_y = mytools.goodmanKruska_tau_y(df,'母亲职业重新编码','父亲职业重新编码')
tau_y
#计算
# Out:
# 0.2565142304504007

# %%
mytools.相关系数强弱判断(tau_y)
# 评价
# 此数据父母职业相关性为弱相关
# Out:
# '弱相关'

# %%
mytools.制作交叉表(df,'母亲职业重新编码','父亲职业重新编码')
# Out:
# 父亲职业重新编码     个体  事业单位       公务员    国企      家庭主妇        民企       All
# 母亲职业重新编码
# 上市公司      0.000   0.0  0.000000  0.00  0.000000  0.083333  0.019608
# 个体        0.500   0.0  0.045455  0.25  0.000000  0.083333  0.137255
# 事业单位      0.000   1.0  0.409091  0.00  0.000000  0.083333  0.235294
# 公务员       0.000   0.0  0.363636  0.00  0.333333  0.250000  0.235294
# 国企        0.000   0.0  0.045455  0.25  0.000000  0.000000  0.039216
# 家庭主妇      0.375   0.0  0.000000  0.25  0.666667  0.416667  0.215686
# 民企        0.125   0.0  0.136364  0.25  0.000000  0.083333  0.117647

# %%
import mytools
mytools.绘制单个类别变量饼图(df,'母亲职业重新编码')

# %%
import mytools
mytools.绘制单个类别变量饼图(df,'父亲职业重新编码')
